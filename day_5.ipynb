# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaTarasiuk/dw_matrix_road_sign/blob/master/day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import pandas as pd
import numpy as np 

import os
import datetime
import matplotlib.pyplot as plt

import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical
from skimage import color, exposure
from sklearn.metrics import accuracy_score

# %load_ext tensorboard

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
cd '/content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

# %%
input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(
      X_train,
      y_train, 
      batch_size=params_fit.get('batch_size', 128),
      epochs=params_fit.get('epochs', 5),
      verbose=params_fit.get('verbose',1),
      validation_data=params_fit.get('validation_data', (X_train, y_train)),
      callbacks= [tensorboard_callback]
  )
  return model

# %%
def predict (model_trained, X_test, y_test, scoring=accuracy_score):
  
  y_test_norm = np.argmax(y_test, axis=1)
  
  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)
  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential ([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu',padding='same'),
    MaxPool2D(),
    Dropout(0.3), 

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3), 

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3), 

    Flatten(),

    Dense(1024, activation='relu'), 
    Dropout(0.3),    
    Dense(1024, activation='relu'), 
    Dropout(0.3),   

    Dense(num_classes, activation='softmax'), 
  ])

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train)

predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 6s 24ms/step - loss: 2.6211 - accuracy: 0.2877 - val_loss: 0.9113 - val_accuracy: 0.7090
# Epoch 2/5
# 272/272 [==============================] - 6s 23ms/step - loss: 0.8427 - accuracy: 0.7329 - val_loss: 0.2151 - val_accuracy: 0.9396
# Epoch 3/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.3891 - accuracy: 0.8780 - val_loss: 0.1158 - val_accuracy: 0.9654
# Epoch 4/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2500 - accuracy: 0.9248 - val_loss: 0.0522 - val_accuracy: 0.9852
# Epoch 5/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.1982 - accuracy: 0.9411 - val_loss: 0.0437 - val_accuracy: 0.9869
# 0.962358276643991

# %%
def get_model(params):
  return Sequential ([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu',padding='same'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_one']), 

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_two']), 

    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_three']), 

    Flatten(),

    Dense(1024, activation='relu'), 
    Dropout(params['dropout_dense_block_one']), 
    Dense(1024, activation='relu'), 
    Dropout(params['dropout_dense_block_two']), 

    Dense(num_classes, activation='softmax'), 
  ])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

  model.fit(
      X_train,
      y_train, 
      batch_size=int(params.get('batch_size', 128)),
      epochs=5,
      verbose=0
  )
  score = model.evaluate(X_test, y_test)
  accuracy = score[1]
  print(params, 'accuracy={}'.format(accuracy))
  return {'loss': -accuracy,'status': STATUS_OK, 'model': model}

# %%
space = {
    'batch_size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one' : hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two' : hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_three' : hp.uniform('dropout_cnn_block_three', 0.3, 0.5),

    'dropout_dense_block_one' : hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two' : hp.uniform('dropout_dense_block_two', 0.3, 0.7),
}

best = fmin(
    func_obj, 
    space,
    tpe.suggest,
    30,
    Trials()
)
# Out:
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.9537 - accuracy: 0.0625
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.7287 - accuracy: 0.7017
#
#  21/138 [===>..........................]
#  - ETA: 0s - loss: 0.7262 - accuracy: 0.7396
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 0.7310 - accuracy: 0.7529
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 0.6887 - accuracy: 0.7638
#
#  50/138 [=========>....................]
#  - ETA: 0s - loss: 0.7719 - accuracy: 0.7375
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.7802 - accuracy: 0.7341
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.7562 - accuracy: 0.7357
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.6751 - accuracy: 0.7654
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 0.6258 - accuracy: 0.7884
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 0.6028 - accuracy: 0.7941
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.6484 - accuracy: 0.7729
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.6103 - accuracy: 0.7916
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.5841 - accuracy: 0.8033
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.5584 - accuracy: 0.8152
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.38679288253601984, 'dropout_cnn_block_three': 0.3862206887379748, 'dropout_cnn_block_two': 0.48371047595386535, 'dropout_dense_block_one': 0.6931155048378744, 'dropout_dense_block_two': 0.685121225725757}
# accuracy=0.8151927590370178
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.4088 - accuracy: 0.0625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 1.6983 - accuracy: 0.4327
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 2.1725 - accuracy: 0.3711
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 1.9170 - accuracy: 0.3924
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 1.8091 - accuracy: 0.4421
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 1.6549 - accuracy: 0.4989
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 1.5898 - accuracy: 0.5142
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 1.4524 - accuracy: 0.5325
#
#  89/138 [==================>...........]
#  - ETA: 0s - loss: 1.3647 - accuracy: 0.5576
#
# 100/138 [====================>.........]
#  - ETA: 0s - loss: 1.3118 - accuracy: 0.5794
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 1.3801 - accuracy: 0.5407
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 1.2689 - accuracy: 0.5788
#
# 128/138 [==========================>...]
#  - ETA: 0s - loss: 1.2363 - accuracy: 0.5879
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 1.2664 - accuracy: 0.5717
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.2682 - accuracy: 0.5746
#
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.49556136500809644, 'dropout_cnn_block_three': 0.48180006842014034, 'dropout_cnn_block_two': 0.4575313026781633, 'dropout_dense_block_one': 0.6694579258339979, 'dropout_dense_block_two': 0.3423606492997185}
# accuracy=0.5746031999588013
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.2859 - accuracy: 0.9062
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.1295 - accuracy: 0.9663
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.0888 - accuracy: 0.9818
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.0783 - accuracy: 0.9818
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.1622 - accuracy: 0.9518
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 0.1458 - accuracy: 0.9571
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.1450 - accuracy: 0.9560
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.1305 - accuracy: 0.9604
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 0.1220 - accuracy: 0.9631
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.1175 - accuracy: 0.9636
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.1315 - accuracy: 0.9614
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 0.1204 - accuracy: 0.9647
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.1115 - accuracy: 0.9675
#
# 135/138 [============================>.]
#  - ETA: 0s - loss: 0.1050 - accuracy: 0.9697
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1030 - accuracy: 0.9701
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.3027861594570564, 'dropout_cnn_block_three': 0.4172555233304457, 'dropout_cnn_block_two': 0.3260934857426045, 'dropout_dense_block_one': 0.6257532436303741, 'dropout_dense_block_two': 0.3511877352536147}
# accuracy=0.9700680375099182
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.5485 - accuracy: 0.4375
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.2218 - accuracy: 0.9261
#
#  20/138 [===>..........................]
#  - ETA: 0s - loss: 0.3635 - accuracy: 0.9109
#
#  30/138 [=====>........................]
#  - ETA: 0s - loss: 0.4637 - accuracy: 0.9115
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.3454 - accuracy: 0.9345
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.3700 - accuracy: 0.9105
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 0.3803 - accuracy: 0.9047
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.3373 - accuracy: 0.9152
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.2974 - accuracy: 0.9240
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.2695 - accuracy: 0.9313
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.2899 - accuracy: 0.9225
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 0.2953 - accuracy: 0.9164
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.2727 - accuracy: 0.9225
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.2542 - accuracy: 0.9276
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2449 - accuracy: 0.9304
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.47410062717846074, 'dropout_cnn_block_three': 0.4531099007979277, 'dropout_cnn_block_two': 0.3255871906366989, 'dropout_dense_block_one': 0.3211869417286815, 'dropout_dense_block_two': 0.5562670954122049}
# accuracy=0.9303854703903198
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.9533 - accuracy: 0.4688
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.2197 - accuracy: 0.9375
#
#  19/138 [===>..........................]
#  - ETA: 0s - loss: 0.3048 - accuracy: 0.9243
#
#  31/138 [=====>........................]
#  - ETA: 0s - loss: 0.4458 - accuracy: 0.9183
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 0.3386 - accuracy: 0.9390
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.3159 - accuracy: 0.9369
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.3004 - accuracy: 0.9356
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 0.2675 - accuracy: 0.9428
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.2387 - accuracy: 0.9488
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.2215 - accuracy: 0.9512
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.2389 - accuracy: 0.9483
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.2188 - accuracy: 0.9527
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.2031 - accuracy: 0.9531
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 0.6624 - accuracy: 0.8845
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 0.4851 - accuracy: 0.8964
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 0.4143 - accuracy: 0.9113
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.3986 - accuracy: 0.9081
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.4438 - accuracy: 0.8858
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.4020 - accuracy: 0.8957
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 0.3579 - accuracy: 0.9075
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.3282 - accuracy: 0.9142
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.2984 - accuracy: 0.9222
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.3440 - accuracy: 0.9028
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.3130 - accuracy: 0.9118
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.2963 - accuracy: 0.9135
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2803 - accuracy: 0.9181
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.41386051616271274, 'dropout_cnn_block_three': 0.48234535599463385, 'dropout_cnn_block_two': 0.36166848048165273, 'dropout_dense_block_one': 0.315719728188068, 'dropout_dense_block_two': 0.46223281874475675}
# accuracy=0.9181405901908875
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.7171 - accuracy: 0.7500
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.3371 - accuracy: 0.8210
#
#  20/138 [===>..........................]
#  - ETA: 0s - loss: 0.4250 - accuracy: 0.8641
#
#  30/138 [=====>........................]
#  - ETA: 0s - loss: 0.4926 - accuracy: 0.8615
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.3878 - accuracy: 0.8926
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 0.3966 - accuracy: 0.8909
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 0.3616 - accuracy: 0.9024
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.3781 - accuracy: 0.8845
#
#  75/138 [===============>..............]
#  - ETA: 0s - loss: 0.3508 - accuracy: 0.8950
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.3253 - accuracy: 0.9029
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.2969 - accuracy: 0.9122
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.3040 - accuracy: 0.9105
#
# 113/138 [=======================>......]
#  - ETA: 0s - loss: 0.2954 - accuracy: 0.9123
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.2738 - accuracy: 0.9188
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.2584 - accuracy: 0.9229
#
# 138/138 [==============================]
#  - 1s 6ms/step - loss: 0.2532 - accuracy: 0.9252
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.4102036520186101, 'dropout_cnn_block_three': 0.3510423686437705, 'dropout_cnn_block_two': 0.34247054901152496, 'dropout_dense_block_one': 0.5871989373186719, 'dropout_dense_block_two': 0.6538629289728062}
# accuracy=0.9251700639724731
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.6040 - accuracy: 0.5625
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.3293 - accuracy: 0.9176
#
#  20/138 [===>..........................]
#  - ETA: 0s - loss: 0.4770 - accuracy: 0.8953
#
#  31/138 [=====>........................]
#  - ETA: 0s - loss: 0.4735 - accuracy: 0.8931
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.3732 - accuracy: 0.9154
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 0.4040 - accuracy: 0.8858
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.4042 - accuracy: 0.8824
#
#  74/138 [===============>..............]
#  - ETA: 0s - loss: 0.3502 - accuracy: 0.8991
#
#  84/138 [=================>............]
#  - ETA: 0s - loss: 0.3122 - accuracy: 0.9103
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.2797 - accuracy: 0.9187
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.2876 - accuracy: 0.9150
#
# 113/138 [=======================>......]
#  - ETA: 0s - loss: 0.2757 - accuracy: 0.9187
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.2556 - accuracy: 0.9247
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.2422 - accuracy: 0.9289
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2323 - accuracy: 0.9324
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.49881608947838457, 'dropout_cnn_block_three': 0.48998210009360316, 'dropout_cnn_block_two': 0.33071138248084614, 'dropout_dense_block_one': 0.3269291135720354, 'dropout_dense_block_two': 0.3732744897627018}
# accuracy=0.9324263334274292
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.4025 - accuracy: 0.0625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.5088 - accuracy: 0.7957
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 0.5926 - accuracy: 0.8324
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 0.5898 - accuracy: 0.8418
#
#  41/138 [=======>......................]
#  - ETA: 0s - loss: 0.4839 - accuracy: 0.8727
#
#  50/138 [=========>....................]
#  - ETA: 0s - loss: 0.5732 - accuracy: 0.8375
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.5581 - accuracy: 0.8357
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.5319 - accuracy: 0.8346
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 0.4675 - accuracy: 0.8538
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.4345 - accuracy: 0.8675
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.3955 - accuracy: 0.8796
#
# 105/138 [=====================>........]
#  - ETA: 0s - loss: 0.4819 - accuracy: 0.8521
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.4448 - accuracy: 0.8638
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.4177 - accuracy: 0.8719
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.4010 - accuracy: 0.8772
#
# 138/138 [==============================]
#  - 1s 6ms/step - loss: 0.3813 - accuracy: 0.8839
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.4398488696653311, 'dropout_cnn_block_three': 0.46833833072846415, 'dropout_cnn_block_two': 0.3907767492543298, 'dropout_dense_block_one': 0.39582512636632067, 'dropout_dense_block_two': 0.5365933294411234}
# accuracy=0.8839002251625061
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.5401 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.4291 - accuracy: 0.8817
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.5566 - accuracy: 0.8555
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 0.4300 - accuracy: 0.8839
#
#  46/138 [=========>....................]
#  - ETA: 0s - loss: 0.4401 - accuracy: 0.8662
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 0.3918 - accuracy: 0.8810
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.3929 - accuracy: 0.8709
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.3353 - accuracy: 0.8900
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.3270 - accuracy: 0.8957
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.3557 - accuracy: 0.8871
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.3600 - accuracy: 0.8879
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.3277 - accuracy: 0.8981
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 0.3261 - accuracy: 0.8955
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.3261 - accuracy: 0.8955
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.45821718915022347, 'dropout_cnn_block_three': 0.4414825935351112, 'dropout_cnn_block_two': 0.4625452639909123, 'dropout_dense_block_one': 0.41000057256515027, 'dropout_dense_block_two': 0.5552069958494956}
# accuracy=0.8954648375511169
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.1165 - accuracy: 0.3125
#
#  10/138 [=>............................]
#  - ETA: 0s - loss: 0.4606 - accuracy: 0.7812
#
#  17/138 [==>...........................]
#  - ETA: 0s - loss: 0.3513 - accuracy: 0.8548
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.6677 - accuracy: 0.8341
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 0.5113 - accuracy: 0.8759
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.5041 - accuracy: 0.8658
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 0.5415 - accuracy: 0.8406
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 0.5068 - accuracy: 0.8531
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.4676 - accuracy: 0.8587
#
#  74/138 [===============>..............]
#  - ETA: 0s - loss: 0.4513 - accuracy: 0.8577
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.4145 - accuracy: 0.8712
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.3846 - accuracy: 0.8825
#
# 100/138 [====================>.........]
#  - ETA: 0s - loss: 0.4170 - accuracy: 0.8703
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.4321 - accuracy: 0.8655
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.3977 - accuracy: 0.8761
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.3744 - accuracy: 0.8822
#
# 138/138 [==============================]
#  - 1s 6ms/step - loss: 0.3546 - accuracy: 0.8884
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.3724111161826631, 'dropout_cnn_block_three': 0.45824902617849067, 'dropout_cnn_block_two': 0.49647901408149636, 'dropout_dense_block_one': 0.46629401868165715, 'dropout_dense_block_two': 0.6309553662771643}
# accuracy=0.8884353637695312
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.7013 - accuracy: 0.0938
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.4329 - accuracy: 0.8654
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.9857 - accuracy: 0.8516
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.6569 - accuracy: 0.8995
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 0.6160 - accuracy: 0.8661
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 0.5298 - accuracy: 0.8814
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.4657 - accuracy: 0.8966
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.4166 - accuracy: 0.9059
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.3797 - accuracy: 0.9141
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.3911 - accuracy: 0.9011
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.3691 - accuracy: 0.9068
#
# 127/138 [==========================>...]
#  - ETA: 0s - loss: 0.3374 - accuracy: 0.9144
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.3185 - accuracy: 0.9193
#
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.3129184627249136, 'dropout_cnn_block_three': 0.3816023609991966, 'dropout_cnn_block_two': 0.36256017202543434, 'dropout_dense_block_one': 0.6584870493963141, 'dropout_dense_block_two': 0.4731688314924598}
# accuracy=0.9192743897438049
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.3840 - accuracy: 0.1250
#
#  10/138 [=>............................]
#  - ETA: 0s - loss: 0.3344 - accuracy: 0.8813
#
#  17/138 [==>...........................]
#  - ETA: 0s - loss: 0.3049 - accuracy: 0.9026
#
#  28/138 [=====>........................]
#  - ETA: 0s - loss: 0.7378 - accuracy: 0.8717
#
#  38/138 [=======>......................]
#  - ETA: 0s - loss: 0.5626 - accuracy: 0.8980
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 0.5259 - accuracy: 0.8963
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.4703 - accuracy: 0.8987
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.4469 - accuracy: 0.8934
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.3957 - accuracy: 0.9058
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.3536 - accuracy: 0.9152
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 0.3183 - accuracy: 0.9239
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 0.3092 - accuracy: 0.9257
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.2836 - accuracy: 0.9314
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.2645 - accuracy: 0.9359
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2604 - accuracy: 0.9370
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.3036475265078418, 'dropout_cnn_block_three': 0.3084068968228104, 'dropout_cnn_block_two': 0.4119521556142215, 'dropout_dense_block_one': 0.5337821270510729, 'dropout_dense_block_two': 0.30303091703179763}
# accuracy=0.9369614720344543
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.4358 - accuracy: 0.8438
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.0900 - accuracy: 0.9716
#
#  21/138 [===>..........................]
#  - ETA: 0s - loss: 0.2256 - accuracy: 0.9568
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 0.2134 - accuracy: 0.9502
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 0.1628 - accuracy: 0.9615
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.1991 - accuracy: 0.9469
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.1723 - accuracy: 0.9531
#
#  75/138 [===============>..............]
#  - ETA: 0s - loss: 0.1486 - accuracy: 0.9600
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.1303 - accuracy: 0.9651
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 0.1210 - accuracy: 0.9677
#
# 105/138 [=====================>........]
#  - ETA: 0s - loss: 0.1496 - accuracy: 0.9598
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 0.1358 - accuracy: 0.9636
#
# 127/138 [==========================>...]
#  - ETA: 0s - loss: 0.1264 - accuracy: 0.9660
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1197 - accuracy: 0.9680
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.3020721140952404, 'dropout_cnn_block_three': 0.33099195137737586, 'dropout_cnn_block_two': 0.30212367145051067, 'dropout_dense_block_one': 0.6028320555343133, 'dropout_dense_block_two': 0.39402295081848515}
# accuracy=0.9680272340774536
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.9824 - accuracy: 0.5000
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.1408 - accuracy: 0.9401
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 0.3204 - accuracy: 0.8995
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.2273 - accuracy: 0.9301
#
#  46/138 [=========>....................]
#  - ETA: 0s - loss: 0.2150 - accuracy: 0.9355
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.1824 - accuracy: 0.9459
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.1858 - accuracy: 0.9431
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.1636 - accuracy: 0.9501
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.1482 - accuracy: 0.9549
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.1338 - accuracy: 0.9595
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 0.1459 - accuracy: 0.9560
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.1336 - accuracy: 0.9597
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.1247 - accuracy: 0.9627
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1190 - accuracy: 0.9649
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.3467374648188569, 'dropout_cnn_block_three': 0.30374947529211194, 'dropout_cnn_block_two': 0.3014526909516098, 'dropout_dense_block_one': 0.586247376029673, 'dropout_dense_block_two': 0.3940663394597321}
# accuracy=0.9648526310920715
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.3510 - accuracy: 0.0625
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.3668 - accuracy: 0.8880
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 0.5233 - accuracy: 0.8601
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 0.4124 - accuracy: 0.8788
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.3799 - accuracy: 0.8878
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.3998 - accuracy: 0.8705
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.3617 - accuracy: 0.8839
#
#  73/138 [==============>...............]
#  - ETA: 0s - loss: 0.3273 - accuracy: 0.8951
#
#  84/138 [=================>............]
#  - ETA: 0s - loss: 0.2915 - accuracy: 0.9070
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.2640 - accuracy: 0.9162
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.3022 - accuracy: 0.8960
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 0.2733 - accuracy: 0.9065
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.2617 - accuracy: 0.9079
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2515 - accuracy: 0.9118
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.30814869004632367, 'dropout_cnn_block_three': 0.42484157049986987, 'dropout_cnn_block_two': 0.3134035324064459, 'dropout_dense_block_one': 0.6996344558433313, 'dropout_dense_block_two': 0.41276972298953263}
# accuracy=0.9117913842201233
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.6997 - accuracy: 0.1250
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.3004 - accuracy: 0.9010
#
#  18/138 [==>...........................]
#  - ETA: 0s - loss: 0.3134 - accuracy: 0.9010
#
#  29/138 [=====>........................]
#  - ETA: 0s - loss: 0.2892 - accuracy: 0.9041
#
#  40/138 [=======>......................]
#  - ETA: 0s - loss: 0.2173 - accuracy: 0.9297
#
#  50/138 [=========>....................]
#  - ETA: 0s - loss: 0.2125 - accuracy: 0.9350
#
#  60/138 [============>.................]
#  - ETA: 0s - loss: 0.2011 - accuracy: 0.9385
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.1820 - accuracy: 0.9460
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.1578 - accuracy: 0.9533
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.1537 - accuracy: 0.9543
#
# 100/138 [====================>.........]
#  - ETA: 0s - loss: 0.1460 - accuracy: 0.9575
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 0.1598 - accuracy: 0.9545
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 0.1467 - accuracy: 0.9583
#
# 128/138 [==========================>...]
#  - ETA: 0s - loss: 0.1389 - accuracy: 0.9607
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 0.1318 - accuracy: 0.9628
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1318 - accuracy: 0.9628
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.3896926648302612, 'dropout_cnn_block_three': 0.32868254621346255, 'dropout_cnn_block_two': 0.3891562438296219, 'dropout_dense_block_one': 0.6164231524044899, 'dropout_dense_block_two': 0.35962595766568795}
# accuracy=0.9628117680549622
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.3793 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.4938 - accuracy: 0.8638
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.5533 - accuracy: 0.8510
#
#  38/138 [=======>......................]
#  - ETA: 0s - loss: 0.3849 - accuracy: 0.8972
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.4065 - accuracy: 0.8691
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.3736 - accuracy: 0.8820
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.3311 - accuracy: 0.8969
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.2981 - accuracy: 0.9070
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 0.2686 - accuracy: 0.9167
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.2578 - accuracy: 0.9187
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.2718 - accuracy: 0.9141
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.2489 - accuracy: 0.9217
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.2305 - accuracy: 0.9280
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2222 - accuracy: 0.9311
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.30188087813688735, 'dropout_cnn_block_three': 0.4216220178408179, 'dropout_cnn_block_two': 0.4202763879816179, 'dropout_dense_block_one': 0.5551393830236601, 'dropout_dense_block_two': 0.43140241158754317}
# accuracy=0.9310657382011414
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.8623 - accuracy: 0.3438
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.3755 - accuracy: 0.9034
#
#  21/138 [===>..........................]
#  - ETA: 0s - loss: 0.3342 - accuracy: 0.9167
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 0.2211 - accuracy: 0.9453
#
#  40/138 [=======>......................]
#  - ETA: 0s - loss: 0.1779 - accuracy: 0.9563
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.2312 - accuracy: 0.9400
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.2041 - accuracy: 0.9472
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.1875 - accuracy: 0.9516
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.1697 - accuracy: 0.9565
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 0.1512 - accuracy: 0.9604
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.1492 - accuracy: 0.9593
#
# 112/138 [=======================>......]
#  - ETA: 0s - loss: 0.1496 - accuracy: 0.9595
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.1385 - accuracy: 0.9626
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.1278 - accuracy: 0.9652
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1361 - accuracy: 0.9628
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.31950066660892945, 'dropout_cnn_block_three': 0.3309362540497596, 'dropout_cnn_block_two': 0.3171357209097333, 'dropout_dense_block_one': 0.6012183564315658, 'dropout_dense_block_two': 0.3833041526469637}
# accuracy=0.9628117680549622
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.0803 - accuracy: 0.4688
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.2057 - accuracy: 0.9135
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.4422 - accuracy: 0.8932
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.3207 - accuracy: 0.9228
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.2610 - accuracy: 0.9368
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.2532 - accuracy: 0.9335
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.2250 - accuracy: 0.9408
#
#  75/138 [===============>..............]
#  - ETA: 0s - loss: 0.2004 - accuracy: 0.9471
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.1796 - accuracy: 0.9515
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 0.1635 - accuracy: 0.9561
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 0.1693 - accuracy: 0.9544
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.1541 - accuracy: 0.9585
#
# 133/138 [===========================>..]
#  - ETA: 0s - loss: 0.1439 - accuracy: 0.9617
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1443 - accuracy: 0.9621
#
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3440806245100738, 'dropout_cnn_block_three': 0.4120936386398488, 'dropout_cnn_block_two': 0.3005465689075955, 'dropout_dense_block_one': 0.45862224172167154, 'dropout_dense_block_two': 0.44854523752071485}
# accuracy=0.9621315002441406
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.5660 - accuracy: 0.8750
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.3798 - accuracy: 0.9423
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 0.6582 - accuracy: 0.8927
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.5115 - accuracy: 0.9007
#
#  45/138 [========>.....................]
#  - ETA: 0s - loss: 0.4562 - accuracy: 0.9028
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.4628 - accuracy: 0.8881
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.4248 - accuracy: 0.8928
#
#  73/138 [==============>...............]
#  - ETA: 0s - loss: 0.4021 - accuracy: 0.8981
#
#  85/138 [=================>............]
#  - ETA: 0s - loss: 0.3580 - accuracy: 0.9103
#
#  96/138 [===================>..........]
#  - ETA: 0s - loss: 0.3236 - accuracy: 0.9183
#
# 107/138 [======================>.......]
#  - ETA: 0s - loss: 0.3579 - accuracy: 0.9022
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.3307 - accuracy: 0.9108
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.3276 - accuracy: 0.9087
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.3170 - accuracy: 0.9113
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.38762846049469907, 'dropout_cnn_block_three': 0.32502307880065495, 'dropout_cnn_block_two': 0.3795266492338504, 'dropout_dense_block_one': 0.6862666986598799, 'dropout_dense_block_two': 0.5040450272726187}
# accuracy=0.9113378524780273
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.1646 - accuracy: 0.5312
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.2897 - accuracy: 0.9323
#
#  21/138 [===>..........................]
#  - ETA: 0s - loss: 0.3830 - accuracy: 0.9122
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 0.2835 - accuracy: 0.9307
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.2477 - accuracy: 0.9396
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 0.3198 - accuracy: 0.9074
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.3016 - accuracy: 0.9077
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.2653 - accuracy: 0.9205
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.2457 - accuracy: 0.9259
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 0.2318 - accuracy: 0.9288
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.2474 - accuracy: 0.9252
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.2258 - accuracy: 0.9318
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.2144 - accuracy: 0.9358
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2077 - accuracy: 0.9376
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.3000881663214817, 'dropout_cnn_block_three': 0.42629605113163593, 'dropout_cnn_block_two': 0.4323053782125511, 'dropout_dense_block_one': 0.6410368032650116, 'dropout_dense_block_two': 0.35242727851927824}
# accuracy=0.9376417398452759
# 100%|██████████| 30/30 [10:15<00:00, 20.53s/it, best loss: -0.9700680375099182]
